# %%
#importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#reading given dataset for Wholesale Customers
cust = pd.read_csv("Wholesale Customer.csv")

# %%
#Checking first and last five rows for checking dataset is clearly read or not
cust.head()
# Out:
#    Buyer/Spender Channel Region  Fresh  Milk  Grocery  Frozen  \
# 0              1  Retail  Other  12669  9656     7561     214
# 1              2  Retail  Other   7057  9810     9568    1762
# 2              3  Retail  Other   6353  8808     7684    2405
# 3              4   Hotel  Other  13265  1196     4221    6404
# 4              5  Retail  Other  22615  5410     7198    3915
#
#    Detergents_Paper  Delicatessen
# 0              2674          1338
# 1              3293          1776
# 2              3516          7844
# 3               507          1788
# 4              1777          5185

# %%
cust.isnull().sum()
# Out:
# Buyer/Spender       0
# Channel             0
# Region              0
# Fresh               0
# Milk                0
# Grocery             0
# Frozen              0
# Detergents_Paper    0
# Delicatessen        0
# dtype: int64

# %%
cust.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440 entries, 0 to 439
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Buyer/Spender     440 non-null    int64
#  1   Channel           440 non-null    object
#  2   Region            440 non-null    object
#  3   Fresh             440 non-null    int64
#  4   Milk              440 non-null    int64
#  5   Grocery           440 non-null    int64
#  6   Frozen            440 non-null    int64
#  7   Detergents_Paper  440 non-null    int64
#  8   Delicatessen      440 non-null    int64
# dtypes: int64(7), object(2)
# memory usage: 27.6+ KB

# %%
cust.drop(['Buyer/Spender'],axis=1, inplace=True)

# %%
cust.describe(include='all')
# Out:
#        Channel Region          Fresh          Milk       Grocery  \
# count      440    440     440.000000    440.000000    440.000000
# unique       2      3            NaN           NaN           NaN
# top      Hotel  Other            NaN           NaN           NaN
# freq       298    316            NaN           NaN           NaN
# mean       NaN    NaN   12000.297727   5796.265909   7951.277273
# std        NaN    NaN   12647.328865   7380.377175   9503.162829
# min        NaN    NaN       3.000000     55.000000      3.000000
# 25%        NaN    NaN    3127.750000   1533.000000   2153.000000
# 50%        NaN    NaN    8504.000000   3627.000000   4755.500000
# 75%        NaN    NaN   16933.750000   7190.250000  10655.750000
# max        NaN    NaN  112151.000000  73498.000000  92780.000000
#
#               Frozen  Detergents_Paper  Delicatessen
# count     440.000000        440.000000    440.000000
# unique           NaN               NaN           NaN
# ...

# %%
cust['Total Spend']=cust.sum(axis=1)

# %%
cust.head()
# Out:
#   Channel Region  Fresh  Milk  Grocery  Frozen  Detergents_Paper  \
# 0  Retail  Other  12669  9656     7561     214              2674
# 1  Retail  Other   7057  9810     9568    1762              3293
# 2  Retail  Other   6353  8808     7684    2405              3516
# 3   Hotel  Other  13265  1196     4221    6404               507
# 4  Retail  Other  22615  5410     7198    3915              1777
#
#    Delicatessen  Total Spend
# 0          1338        34112
# 1          1776        33266
# 2          7844        36610
# 3          1788        27381
# 4          5185        46100

# %%
cust.describe(include='all')
# Out:
#        Channel Region          Fresh          Milk       Grocery  \
# count      440    440     440.000000    440.000000    440.000000
# unique       2      3            NaN           NaN           NaN
# top      Hotel  Other            NaN           NaN           NaN
# freq       298    316            NaN           NaN           NaN
# mean       NaN    NaN   12000.297727   5796.265909   7951.277273
# std        NaN    NaN   12647.328865   7380.377175   9503.162829
# min        NaN    NaN       3.000000     55.000000      3.000000
# 25%        NaN    NaN    3127.750000   1533.000000   2153.000000
# 50%        NaN    NaN    8504.000000   3627.000000   4755.500000
# 75%        NaN    NaN   16933.750000   7190.250000  10655.750000
# max        NaN    NaN  112151.000000  73498.000000  92780.000000
#
#               Frozen  Detergents_Paper  Delicatessen    Total Spend
# count     440.000000        440.000000    440.000000     440.000000
# ...

# %%
cust.groupby('Region')['Total Spend'].sum()
# Out:
# Region
# Lisbon     2386813
# Oporto     1555088
# Other     10677599
# Name: Total Spend, dtype: int64

# %%
reg = cust.groupby('Region')['Total Spend'].sum().plot(kind='bar', ylabel='Total Spend')

# %%
cust.groupby('Channel')['Total Spend'].sum()
# Out:
# Channel
# Hotel     7999569
# Retail    6619931
# Name: Total Spend, dtype: int64

# %%
cust.groupby('Channel')['Total Spend'].sum().plot(kind='bar', ylabel='Total Spend')

# %%
a=cust.groupby('Channel')['Fresh'].var()

# %%
(cust.groupby('Channel')['Fresh'].std())/(cust.groupby('Channel')['Fresh'].mean()*100)
# Out:
# Channel
# Hotel     0.010264
# Retail    0.010094
# Name: Fresh, dtype: float64

# %%
(cust.groupby('Region')['Fresh'].std())/(cust.groupby('Region')['Fresh'].mean())
# Out:
# Region
# Lisbon    1.041049
# Oporto    0.848318
# Other     1.068277
# Name: Fresh, dtype: float64

# %%
pd.pivot_table(cust, index=['Channel'],  aggfunc=sum)
# Out:
#          Delicatessen  Detergents_Paper    Fresh   Frozen  Grocery     Milk  \
# Channel
# Hotel          421955            235587  4015717  1116979  1180717  1028614
# Retail         248988           1032270  1264414   234671  2317845  1521743
#
#          Total Spend
# Channel
# Hotel        7999569
# Retail       6619931

# %%
pd.pivot_table(cust, index=['Region'],  aggfunc=sum)
# Out:
#         Delicatessen  Detergents_Paper    Fresh  Frozen  Grocery     Milk  \
# Region
# Lisbon        104327            204136   854833  231026   570037   422454
# Oporto         54506            173311   464721  190132   433274   239144
# Other         512110            890410  3960577  930492  2495251  1888759
#
#         Total Spend
# Region
# Lisbon      2386813
# Oporto      1555088
# Other      10677599

# %%
pd.pivot_table(cust, index=['Channel','Region'],  aggfunc=sum)
# Out:
#                 Delicatessen  Detergents_Paper    Fresh  Frozen  Grocery  \
# Channel Region
# Hotel   Lisbon         70632             56081   761233  184512   237542
#         Oporto         30965             13516   326215  160861   123074
#         Other         320358            165990  2928269  771606   820101
# Retail  Lisbon         33695            148055    93600   46514   332495
#         Oporto         23541            159795   138506   29271   310200
#         Other         191752            724420  1032308  158886  1675150
#
#                    Milk  Total Spend
# Channel Region
# Hotel   Lisbon   228342      1538342
#         Oporto    64519       719150
#         Other    735753      5742077
# Retail  Lisbon   194112       848471
#         Oporto   174625       835938
#         Other   1153006      4935522

# %%
cust.isnull().sum()
# Out:
# Channel             0
# Region              0
# Fresh               0
# Milk                0
# Grocery             0
# Frozen              0
# Detergents_Paper    0
# Delicatessen        0
# Total Spend         0
# dtype: int64

# %%
sns.barplot(x="Region",y="Total Spend",hue="Region", data=cust).grid(True)

# %%
sns.barplot(x="Channel",y="Total Spend",hue="Channel", data=cust).grid(True)

# %%
cust.groupby("Channel").sum().plot(kind='bar')

# %%
sns.pairplot(cust)

# %%
cust.hist(figsize=(40,40))
plt.xticks(fontsize=40)
# Out:
# (array([0. , 0.2, 0.4, 0.6, 0.8, 1. ]),
#  <a list of 6 Text major ticklabel objects>)

# %%
cust["Buyer/Spender"]=cust.astype(str)

# %%
cust.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440 entries, 0 to 439
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Buyer/Spender     440 non-null    object
#  1   Channel           440 non-null    object
#  2   Region            440 non-null    object
#  3   Fresh             440 non-null    int64
#  4   Milk              440 non-null    int64
#  5   Grocery           440 non-null    int64
#  6   Frozen            440 non-null    int64
#  7   Detergents_Paper  440 non-null    int64
#  8   Delicatessen      440 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 25.8+ KB

# %%
cust["Fresh"].hist()

# %%
cust.boxplot()

# %%
sns.catplot(x="Region" , y="Fresh" , hue="Channel",data=cust , kind="box")

# %%
sns.catplot(x="Channel" , y="Fresh" , hue="Region",data=cust , kind="box")

# %%
sns.catplot(x="Milk" , y="Region" , hue="Channel",data=cust)

# %%
Region1=cust.groupby("Region").sum()
Region1
# Out:
#           Fresh     Milk  Grocery  Frozen  Detergents_Paper  Delicatessen
# Region
# Lisbon   854833   422454   570037  231026            204136        104327
# Oporto   464721   239144   433274  190132            173311         54506
# Other   3960577  1888759  2495251  930492            890410        512110

# %%
Channel1=cust.groupby("Channel").sum()
Channel1
# Out:
#            Fresh     Milk  Grocery   Frozen  Detergents_Paper  Delicatessen
# Channel
# Hotel    4015717  1028614  1180717  1116979            235587        421955
# Retail   1264414  1521743  2317845   234671           1032270        248988

# %%
cust.pivot_table(index=['Channel'], values=['Fresh', 'Milk'], aggfunc='sum')
# Out:
#            Fresh     Milk
# Channel
# Hotel    4015717  1028614
# Retail   1264414  1521743

# %%
Region1.boxplot()

# %%
Region1.max()
# Out:
# Fresh               3960577
# Milk                1888759
# Grocery             2495251
# Frozen               930492
# Detergents_Paper     890410
# Delicatessen         512110
# dtype: int64

# %%
Channel1.max()
# Out:
# Fresh               4015717
# Milk                1521743
# Grocery             2317845
# Frozen              1116979
# Detergents_Paper    1032270
# Delicatessen         421955
# dtype: int64

# %%
plt.figure(figsize=(7,7))
sns.barplot(x="Channel", y="Fresh", hue="Region", data=cust)

# %%
plt.figure(figsize=(7,7))
sns.barplot(x="Region", y="Fresh", hue="Channel", data=cust)

# %%
sns.barplot(x="Channel", y="Milk", hue="Region", data=cust)

# %%
sns.barplot(x="Region", y="Milk", hue="Channel", data=cust)

# %%
sns.barplot(x="Channel", y="Grocery", hue="Region", data=cust)

# %%
sns.barplot(x="Region", y="Grocery", hue="Channel", data=cust)

# %%
sns.barplot(x="Channel", y="Frozen", hue="Region", data=cust)

# %%
sns.barplot(x="Channel", y="Detergents_Paper", hue="Region", data=cust)

# %%
sns.barplot(x="Channel", y="Delicatessen", hue="Region", data=cust)

# %%
cust["sum"] = cust.sum(axis=1)

# %%
cust.head()
# Out:
#   Buyer/Spender Channel Region  Fresh  Milk  Grocery  Frozen  \
# 0             1  Retail  Other  12669  9656     7561     214
# 1             2  Retail  Other   7057  9810     9568    1762
# 2             3  Retail  Other   6353  8808     7684    2405
# 3             4   Hotel  Other  13265  1196     4221    6404
# 4             5  Retail  Other  22615  5410     7198    3915
#
#    Detergents_Paper  Delicatessen    sum
# 0              2674          1338  34112
# 1              3293          1776  33266
# 2              3516          7844  36610
# 3               507          1788  27381
# 4              1777          5185  46100

# %%
sns.boxplot(x="Channel", y="sum", hue="Region", data=cust)

# %%
type_counts = cust['Region'].value_counts()
df2 = pd.DataFrame({'Region': type_counts})
df2.plot.pie(y='Region', figsize=(5,5), autopct='%1.1f%%')

# %%
type_counts = cust['Channel'].value_counts()
df2 = pd.DataFrame({'Channel': type_counts})
df2.plot.pie(y='Channel', figsize=(5,5), autopct='%1.1f%%')

# %%
plt.figure(figsize=(30,30))
plt.xticks(fontsize=30)
plt.yticks(fontsize=30)
sns.boxplot(data=cust)

# %%
new1=pd.DataFrame(pd.pivot_table(cust, index=['Region']))

# %%
new1
# Out:
#         Buyer/Spender  Delicatessen  Detergents_Paper         Fresh  \
# Region
# Lisbon     235.000000   1354.896104       2651.116883  11101.727273
# Oporto     317.000000   1159.702128       3687.468085   9887.680851
# Other      202.613924   1620.601266       2817.753165  12533.471519
#
#              Frozen      Grocery         Milk
# Region
# Lisbon  3000.337662  7403.077922  5486.415584
# Oporto  4045.361702  9218.595745  5088.170213
# Other   2944.594937  7896.363924  5977.085443

# %%
new1.describe()
# Out:
#        Buyer/Spender  Delicatessen  Detergents_Paper         Fresh  \
# count       3.000000      3.000000          3.000000      3.000000
# mean      251.537975   1378.399832       3052.112711  11174.293214
# std        58.959071    231.346759        556.506290   1324.387189
# min       202.613924   1159.702128       2651.116883   9887.680851
# 25%       218.806962   1257.299116       2734.435024  10494.704062
# 50%       235.000000   1354.896104       2817.753165  11101.727273
# 75%       276.000000   1487.748685       3252.610625  11817.599396
# max       317.000000   1620.601266       3687.468085  12533.471519
#
#             Frozen      Grocery         Milk
# count     3.000000     3.000000     3.000000
# mean   3330.098100  8172.679197  5517.223747
# std     620.063164   938.769854   445.257711
# min    2944.594937  7403.077922  5088.170213
# 25%    2972.466300  7649.720923  5287.292899
# 50%    3000.337662  7896.363924  5486.415584
# ...

# %%
new1.std()
# Out:
# Buyer/Spender         58.959071
# Delicatessen         231.346759
# Detergents_Paper     556.506290
# Fresh               1324.387189
# Frozen               620.063164
# Grocery              938.769854
# Milk                 445.257711
# dtype: float64

# %%
new1.mean()
# Out:
# Buyer/Spender         251.537975
# Delicatessen         1378.399832
# Detergents_Paper     3052.112711
# Fresh               11174.293214
# Frozen               3330.098100
# Grocery              8172.679197
# Milk                 5517.223747
# dtype: float64

# %%
new2=pd.DataFrame(pd.pivot_table(cust, index=['Channel']))

# %%
new2
# Out:
#          Delicatessen  Detergents_Paper         Fresh       Frozen  \
# Channel
# Hotel     1415.956376        790.560403  13475.560403  3748.251678
# Retail    1753.436620       7269.507042   8904.323944  1652.612676
#
#               Grocery          Milk   Total Spend
# Channel
# Hotel     3962.137584   3451.724832  26844.191275
# Retail   16322.852113  10716.500000  46619.232394

# %%
var1=new1.mean()/new1.std()
var1
# Out:
# Delicatessen         5.958155
# Detergents_Paper     5.484417
# Fresh                8.437331
# Frozen               5.370579
# Grocery              8.705732
# Milk                12.391080
# Total Spend         22.462849
# dtype: float64

# %%
cust.std()
# Out:
# Buyer/Spender         127.161315
# Fresh               12647.328865
# Milk                 7380.377175
# Grocery              9503.162829
# Frozen               4854.673333
# Detergents_Paper     4767.854448
# Delicatessen         2820.105937
# dtype: float64

# %%
cust.mean()
# Out:
# Buyer/Spender         220.500000
# Fresh               12000.297727
# Milk                 5796.265909
# Grocery              7951.277273
# Frozen               3071.931818
# Detergents_Paper     2881.493182
# Delicatessen         1524.870455
# dtype: float64

# %%
cv=cust.std()/cust.mean()
cv
# Out:
# Buyer/Spender       0.576695
# Fresh               1.053918
# Milk                1.273299
# Grocery             1.195174
# Frozen              1.580332
# Detergents_Paper    1.654647
# Delicatessen        1.849407
# dtype: float64

# %%
var2=new2.mean()/new2.std()
var2
# Out:
# Delicatessen        6.640683
# Detergents_Paper    0.879669
# Fresh               3.461857
# Frozen              1.822350
# Grocery             1.160423
# Milk                1.379044
# Total Spend         2.626871
# dtype: float64

# %%
new1.describe()
# Out:
#        Delicatessen  Detergents_Paper         Fresh       Frozen      Grocery  \
# count      3.000000          3.000000      3.000000     3.000000     3.000000
# mean    1378.399832       3052.112711  11174.293214  3330.098100  8172.679197
# std      231.346759        556.506290   1324.387189   620.063164   938.769854
# min     1159.702128       2651.116883   9887.680851  2944.594937  7403.077922
# 25%     1257.299116       2734.435024  10494.704062  2972.466300  7649.720923
# 50%     1354.896104       2817.753165  11101.727273  3000.337662  7896.363924
# 75%     1487.748685       3252.610625  11817.599396  3522.849682  8557.479834
# max     1620.601266       3687.468085  12533.471519  4045.361702  9218.595745
#
#               Milk   Total Spend
# count     3.000000      3.000000
# mean   5517.223747  32624.806802
# std     445.257711   1452.389529
# min    5088.170213  30997.571429
# 25%    5287.292899  32042.275076
# 50%    5486.415584  33086.978723
# ...

# %%
new2.describe()
# Out:
#        Delicatessen  Detergents_Paper         Fresh       Frozen  \
# count      2.000000          2.000000      2.000000     2.000000
# mean    1584.696498       4030.033722  11189.942173  2700.432177
# std      238.634569       4581.307104   3232.352299  1481.840549
# min     1415.956376        790.560403   8904.323944  1652.612676
# 25%     1500.326437       2410.297063  10047.133058  2176.522427
# 50%     1584.696498       4030.033722  11189.942173  2700.432177
# 75%     1669.066559       5649.770382  12332.751288  3224.341927
# max     1753.436620       7269.507042  13475.560403  3748.251678
#
#             Grocery          Milk   Total Spend
# count      2.000000      2.000000      2.000000
# mean   10142.494848   7084.112416  36731.711835
# std     8740.345064   5136.971785  13983.065674
# min     3962.137584   3451.724832  26844.191275
# 25%     7052.316216   5267.918624  31787.951555
# 50%    10142.494848   7084.112416  36731.711835
# ...

# %%
corr = cust.corr()
corr
# Out:
#                   Buyer/Spender     Fresh      Milk   Grocery    Frozen  \
# Buyer/Spender          1.000000 -0.061151 -0.162290 -0.140509  0.053802
# Fresh                 -0.061151  1.000000  0.100510 -0.011854  0.345881
# Milk                  -0.162290  0.100510  1.000000  0.728335  0.123994
# Grocery               -0.140509 -0.011854  0.728335  1.000000 -0.040193
# Frozen                 0.053802  0.345881  0.123994 -0.040193  1.000000
# Detergents_Paper      -0.134365 -0.101953  0.661816  0.924641 -0.131525
# Delicatessen          -0.101845  0.244690  0.406368  0.205497  0.390947
#
#                   Detergents_Paper  Delicatessen
# Buyer/Spender            -0.134365     -0.101845
# Fresh                    -0.101953      0.244690
# Milk                      0.661816      0.406368
# Grocery                   0.924641      0.205497
# Frozen                   -0.131525      0.390947
# Detergents_Paper          1.000000      0.069291
# ...

# %%
sns.heatmap(corr, annot=True)
